# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
# Loading data 
soil = pd.read_csv('soil_raw.csv', delimiter=',')
soil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383 entries, 0 to 382
# Data columns (total 48 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   OBJECTID   383 non-null    int64
#  1   SSAMPLENO  383 non-null    object
#  2   LONGITUDE  383 non-null    float64
#  3   LATITUDE   383 non-null    float64
#  4   SIO2       383 non-null    float64
#  5   AL2O3      383 non-null    float64
#  6   FE2O3      383 non-null    float64
#  7   TIO2       383 non-null    float64
#  8   CAO        383 non-null    float64
#  9   MGO        383 non-null    float64
#  10  MNO        383 non-null    float64
#  11  NA2O       383 non-null    float64
#  12  K2O        383 non-null    float64
#  13  P2O5       383 non-null    float64
#  14  BA         383 non-null    float64
#  15  GA         383 non-null    float64
#  16  SC         383 non-null    float64
#  17  V          383 non-null    float64
#  18  TH         383 non-null    float64
#  19  PB         383 non-null    float64
#  20  NI         383 non-null    float64
#  21  CO         383 non-null    float64
#  22  RB         383 non-null    float64
#  23  SR         383 non-null    float64
#  24  Y          383 non-null    float64
#  25  ZR         383 non-null    float64
#  26  NB         383 non-null    float64
#  27  CR         383 non-null    float64
#  28  CU         383 non-null    float64
#  29  ZN         383 non-null    float64
#  30  LA         383 non-null    float64
#  31  CE         383 non-null    float64
#  32  PR         383 non-null    float64
#  33  ND         383 non-null    float64
#  34  SM         383 non-null    float64
#  35  EU         383 non-null    float64
#  36  TB         383 non-null    float64
#  37  GD         383 non-null    float64
#  38  DY         383 non-null    float64
#  39  HO         383 non-null    float64
#  40  ER         383 non-null    float64
#  41  TM         383 non-null    float64
#  42  YB         383 non-null    float64
#  43  LU         383 non-null    float64
#  44  HF         383 non-null    float64
#  45  TA         383 non-null    float64
#  46  U          383 non-null    float64
#  47  TREE       383 non-null    float64
# dtypes: float64(46), int64(1), object(1)
# memory usage: 143.8+ KB

# %%
soil_major = soil.iloc[:,4:14]
soil_minor = soil.iloc[:, 14: ]
log_minor = soil_minor.apply(np.log1p)

# %%
#Apply PCA for dimensionality 
# Feature selection
from sklearn.decomposition import PCA
# Step 4: Apply StandardScaler to the combined DataFrame
scaler = StandardScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(log_soil), columns=log_soil.columns)
df_scaled.hist(figsize=(18, 12), bins=30, edgecolor='blue')  # bigger figure, more bins
plt.suptitle('Histograms of Log-Transformed Soil Variables', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.96])  # leave space for suptitle
plt.savefig('Histogram_std_log_soil.png')
plt.show()

# %%
log_soil['SIO2'] = soil['SIO2']
log_soil['AL2O3'] = soil['AL2O3']
soil_corr = log_soil.corr()
# Out:
# <Axes: >

# %%
# Set figure size (adjust width & height as needed)
plt.figure(figsize=(30, 20))  # width=12 inches, height=10 inches

# Draw the heatmap
sns.heatmap(soil_corr, cmap='coolwarm', annot=True, fmt=".2f", square=True)

# Optional: add a title
plt.title('Correlation Heatmap')

plt.tight_layout()
plt.savefig('Heatmap_correlation_matrix_soil.png')
plt.show()

# %%
Corr_sam = soil_corr[['LA','CE','SM','Y','NB']]
# Set figure size (adjust width & height as needed)
plt.figure(figsize=(30, 20))  # width=12 inches, height=10 inches

# Draw the heatmap
sns.heatmap(Corr_sam.T, cmap='coolwarm', annot=True, fmt=".2f", square=True, cbar_kws={'shrink': 0.25}, annot_kws={"size": 10})

# Optional: add a title
plt.title('Correlation Heatmap')

plt.tight_layout()
plt.savefig('Heatmap_correlation_matrix_LACENBY_soil.png')
plt.show()

# %%
#Apply PCA for dimensionality 
# Feature selection
from sklearn.decomposition import PCA
# Step 4: Apply StandardScaler to the combined DataFrame
scaler = StandardScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(log_soil), columns=log_soil.columns)

#Apply PCA for dimensionality 
# Feature selection
from sklearn.decomposition import PCA
pca = PCA(n_components=2)  # Reduce to 2 components for visualization
pca_components = pca.fit_transform(df_scaled)
pca_loadings = pca.components_.T  # Loadings for the features

# Create a DataFrame for PCA loadings
pca_loadings_df = pd.DataFrame(pca_loadings, columns=['PC1', 'PC2'], index=df_scaled.columns)

# Plot PCA results with feature loadings
plt.figure(figsize=(10, 8))
plt.axhline(0, color='grey', linestyle='--')
plt.axvline(0, color='grey', linestyle='--')
sns.scatterplot(data=pca_loadings_df, x='PC1', y='PC2', s=100, color='blue')

# Add feature labels
for feature in pca_loadings_df.index:
    plt.text(pca_loadings_df.loc[feature, 'PC1'], pca_loadings_df.loc[feature, 'PC2'], feature,
             fontsize=12, ha='right', va='bottom')

# Add titles and labels
plt.title('PCA Biplot of Features')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.grid(True)
plt.savefig('PCA.png', format='png', bbox_inches='tight')
plt.savefig('PCA_soil.png')
plt.show()
plt.close()

# %%
soil.describe().T
# Out:
#            count         mean          std        min         25%       50%  \
# OBJECTID   383.0  2691.078329  1202.980545  1200.0000  2200.50000  2364.000
# LONGITUDE  383.0    76.884420     0.483816    76.0103    76.46695    76.875
# LATITUDE   383.0    14.894763     0.514206    13.7750    14.46615    14.897
# SIO2       383.0    52.530809    12.494904     0.0000    49.72500    55.200
# AL2O3      383.0    16.865587     4.246149     0.0000    14.32500    17.690
# FE2O3      383.0     6.957859     4.439160     0.0000     4.94000     6.120
# TIO2       383.0     0.679347     0.304448     0.0000     0.50000     0.680
# CAO        383.0     4.828877     6.659873     0.0000     1.30500     2.220
# MGO        383.0     1.872193     2.293595     0.0000     1.03000     1.440
# MNO        383.0     0.135457     0.291718     0.0000     0.05000     0.070
# NA2O       383.0     1.278277     0.958564     0.0000     0.75000     1.180
# K2O        383.0     1.871932     1.017410     0.0000     1.04000     1.800
# P2O5       383.0     0.094047     0.094343     0.0000     0.05000     0.070
# BA         383.0   435.689765   260.599776     0.0000   278.95000   404.600
# GA         383.0    17.408460     7.522517     0.0000    12.00000    17.200
# SC         383.0    20.872141    47.394470     0.0000     8.70000    12.000
# V          383.0    94.743342    52.893144     0.0000    59.90000    87.400
# TH         383.0    16.277023    12.458622     0.0000     7.35000    12.600
# PB         383.0    20.795039    22.039933     0.0000    10.20000    17.000
# NI         383.0    44.865431    33.182816     0.0000    24.15000    35.100
# CO         383.0    16.804439    10.670734     0.0000    10.10000    14.600
# RB         383.0    80.983499    49.072055     0.0000    44.20000    76.000
# SR         383.0   187.981514   128.795100     0.0000   101.05000   151.000
# Y          383.0    27.264047    23.226507     0.0000    16.00000    23.300
# ZR         383.0   413.723890   325.538114     0.0000   204.50000   338.400
# NB         383.0    13.901201    10.247091     0.0000     7.10000    12.000
# CR         383.0    93.607572    72.281477     0.0000    50.60000    73.000
# CU         383.0    36.504386    34.546048     0.0000    18.80000    27.800
# ZN         383.0    51.560313    39.029043     0.0000    27.95000    45.000
# LA         383.0    59.161854    55.784106     0.2500    23.48500    42.590
# CE         383.0   114.440627    94.175425     0.2500    47.74500    84.980
# PR         383.0    12.455248    10.638275     0.2500     5.33000     9.070
# ND         383.0    44.413864    37.818328     0.2500    18.98500    32.150
# SM         383.0     7.627520     5.927335     0.2500     3.80000     5.740
# EU         383.0     1.837232     1.497013     0.0800     1.03000     1.410
# TB         383.0     1.403995     1.769026     0.0300     0.61500     0.880
# GD         383.0     6.234778     5.129182     0.2500     3.35500     4.950
# DY         383.0     5.666292     4.567410     0.1800     3.36500     4.490
# HO         383.0     1.084125     0.899879     0.0300     0.64000     0.870
# ER         383.0     3.154256     2.591114     0.0800     1.87000     2.460
# TM         383.0     0.653394     1.259345     0.0100     0.30000     0.390
# YB         383.0     3.231802     2.592702     0.0800     1.92500     2.530
# LU         383.0     0.508851     0.409137     0.0000     0.30000     0.410
# HF         383.0    14.936475    12.844062     0.1000     6.97000    11.620
# TA         383.0     2.726240     9.880575     0.0900     0.63000     0.960
# U          383.0     3.499478     2.878782     0.0300     1.58000     2.750
# TREE       383.0   255.639060   206.461044     6.1800   110.48000   189.200
#
#                   75%        max
# OBJECTID   2767.50000  8053.0000
# LONGITUDE    77.27085    77.7472
# LATITUDE     15.34540    15.7339
# SIO2         58.77000    84.2700
# AL2O3        19.92500    25.3200
# FE2O3         7.88000    54.5600
# TIO2          0.83000     2.6300
# CAO           4.91000    41.3800
# MGO           2.24500    41.3100
# MNO           0.12000     3.8500
# NA2O          1.69000    13.9000
# K2O           2.59500     4.5700
# P2O5          0.09000     0.7900
# BA          578.05000  1942.8000
# GA           22.15000    41.0000
# SC           16.65000   458.9000
# V           119.10000   336.0000
# TH           23.30000    75.8000
# PB           23.25000   171.7000
# NI           56.20000   220.0000
# CO           20.10000    66.5000
# RB          107.35000   268.3000
# SR          246.00000   758.8000
# Y            31.85000   231.5000
# ZR          526.75000  2189.0000
# NB           17.85000    91.3000
# CR          111.70000   556.3000
# CU           42.40000   372.8000
# ZN           64.00000   331.1000
# LA           75.80000   492.4800
# CE          160.69500   593.5300
# PR           16.46000    86.8200
# ND           58.94500   297.1500
# SM            9.83500    42.4100
# EU            2.18000    17.8400
# TB            1.41500    19.0000
# GD            8.24000    52.9000
# DY            6.42500    63.0400
# HO            1.19500    12.2500
# ER            3.44000    34.9600
# TM            0.59000    14.6500
# YB            3.62000    33.0000
# LU            0.58000     5.1300
# HF           19.41000   102.5700
# TA            1.57000    96.5000
# U             4.62500    21.2500
# TREE        350.76000  1546.3100

# %%
soil['Fe_number'] = soil['FE2O3']/ (soil['FE2O3'] + soil['MGO'])
soil['Alkali Index'] = soil['K2O'] + soil['NA2O']
soil['MALI'] = soil['Alkali Index'] = soil['K2O'] + soil['NA2O'] - soil['CAO']
soil['La_Lu'] = soil['LA']/ soil['LU']
soil['Rb_Sr'] = soil['RB']/ soil['SR']
soil['Ba_Sr'] = soil['BA']/ soil['SR']
soil['Th_U'] = soil['TH']/ soil['U']

# %%
soil_set =  soil.iloc[:, 5:]
plt.figure(figsize=(30, 20))
sns.heatmap(soil_set.corr(), cmap= 'coolwarm', annot=True, fmt=".2f", square=True)
# Out:
# <Axes: >
